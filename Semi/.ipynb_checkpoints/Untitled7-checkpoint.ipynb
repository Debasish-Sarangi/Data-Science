# %%
import numpy as np
from itertools import product
number_of_people = int(input().strip())
Red_Orange= int(input().strip())
Red_Green= int(input().strip())
Orange_Red= int(input().strip())
Orange_Green = int(input().strip())
Green_Red= int(input().strip())
Green_Orange= int(input().strip())

counter=[]
if(Red_Orange!=0):

    if (number_of_people%3==0 ):
        rand_people=np.repeat(['R','O'],number_of_people/3)
    elif(number_of_people%2==0 ):
        rand_people=np.repeat(['R','O'],number_of_people/2)

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='O' and h[1]=='R') ):
            counter.append(h)


if(Red_Green!=0):

    if (number_of_people%3==0 ):
        rand_people=np.repeat(['R','G'],number_of_people/3)
    elif(number_of_people%2==0 ):
        rand_people=np.repeat(['R','G'],number_of_people/2)

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='G' and h[1]=='R')):
            counter.append(h)

if(Orange_Red!=0):
    if (number_of_people%3==0 ):
        rand_people=np.repeat(['O','R'],number_of_people/3)
    elif(number_of_people%2==0 ):
        rand_people=np.repeat(['O','R'],number_of_people/2)

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='R' and h[1]=='O')):
            counter.append(h)

if(Orange_Green!=0):
    if (number_of_people%3==0 ):
        rand_people=np.repeat(['O','G'],number_of_people/3)
    elif(number_of_people%2==0 ):
        rand_people=np.repeat(['O','G'],number_of_people/2)

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='G' and h[1]=='O')):
            counter.append(h)

if(Green_Red!=0):
    if (number_of_people%3==0 ):
        rand_people=np.repeat(['G','R'],number_of_people/3)
    elif(number_of_people%2==0 ):
        rand_people=np.repeat(['G','R'],number_of_people/2)

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='R' and h[1]=='G')):
            counter.append(h)

if(Green_Orange!=0):
    if (number_of_people%3==0 ):
        rand_people=np.repeat(['G','O'],number_of_people/3)
    elif(number_of_people%2==0 ):
        rand_people=np.repeat(['G','O'],number_of_people/2)

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='O' and h[1]=='G')):
            counter.append(h)

            
print(set(counter))
print(len(set(counter)))
# Out:
# 2
# 1
# 1
# 1
# 1
# 0
# 0
# {('R', 'G'), ('R', 'R'), ('O', 'G'), ('O', 'R'), ('R', 'O'), ('O', 'O'), ('G', 'G')}
# 7

# %%
import numpy as np
from itertools import product
number_of_people = int(input().strip())
Red_Orange= int(input().strip())
Red_Green= int(input().strip())
Orange_Red= int(input().strip())
Orange_Green = int(input().strip())
Green_Red= int(input().strip())
Green_Orange= int(input().strip())
# Out:
# 2
# 1
# 1
# 1
# 1
# 0
# 0

# %%
counter=[]
if(Red_Orange!=0):

 
    rand_people=np.repeat(['R','O'],min(round(number_of_people/2),Red_Orange))
    

    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='O' and h[1]=='R') ):
            counter.append(h)


if(Red_Green!=0):

    rand_people=np.repeat(['R','G'],min(round(number_of_people/2),Red_Green))

    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='G' and h[1]=='R')):
            counter.append(h)

if(Orange_Red!=0):
    
    rand_people=np.repeat(['O','R'],min(round(number_of_people/2),Orange_Red))

    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='R' and h[1]=='O')):
            counter.append(h)

if(Orange_Green!=0):
    
    rand_people=np.repeat(['O','G'],min(round(number_of_people/2),Orange_Green))

    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='G' and h[1]=='O')):
            counter.append(h)

if(Green_Red!=0):
    
    rand_people=np.repeat(['G','R'],min(round(number_of_people/2),Green_Red))

    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='R' and h[1]=='G')):
            counter.append(h)

if(Green_Orange!=0):
    
    rand_people=np.repeat(['G','O'],min(round(number_of_people/2),Green_Orange))

    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='O' and h[1]=='G')):
            counter.append(h)


#print(len(counter))            
print(len(set(counter)))

#print(counter)
#print(set(counter))
# Out:
# 7

# %%
counter=[]
if(Red_Orange!=0):

 
    rand_people=np.repeat(['R','O'],min(round(number_of_people/2),Red_Orange))
    

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='O' and h[1]=='R') ):
            counter.append(h)

print(set(counter))
# Out:
# {('R', 'R', 'O', 'R'), ('R', 'O', 'O', 'R'), ('R', 'O', 'R', 'R'), ('O', 'O', 'O', 'O'), ('R', 'O', 'O', 'O'), ('R', 'R', 'R', 'R'), ('R', 'O', 'R', 'O'), ('R', 'R', 'O', 'O'), ('O', 'O', 'R', 'R'), ('R', 'R', 'R', 'O'), ('O', 'O', 'O', 'R'), ('O', 'O', 'R', 'O')}

# %%
counter=[]
if(Green_Red!=0):
    
    rand_people=np.repeat(['G','R'],min(round(number_of_people/2),Green_Red))

    a=product(rand_people,repeat=2)

    for h in a:
        counter.append(h)
        #if(not(h[0]=='R' and h[1]=='G')):
            #counter.append(h)
print(set(counter))
# Out:
# {('G', 'R'), ('R', 'G'), ('R', 'R'), ('G', 'G')}

# %%
def main():

    import numpy as np
    from itertools import product
    number_of_people = int(input().strip())
    Red_Orange= int(input().strip())
    Red_Green= int(input().strip())
    Orange_Red= int(input().strip())
    Orange_Green = int(input().strip())
    Green_Red= int(input().strip())
    Green_Orange= int(input().strip())

    counter=[]
    if(Red_Orange!=0):


        rand_people=np.repeat(['R','O'],min(round(number_of_people/2),Red_Orange))


        a=product(rand_people,repeat=2)

        for h in a:
            if(not(h[0]=='O' and h[1]=='R') ):
                counter.append(h)


    if(Red_Green!=0):

        rand_people=np.repeat(['R','G'],min(round(number_of_people/2),Red_Green))

        a=product(rand_people,repeat=2)

        for h in a:
            if(not(h[0]=='G' and h[1]=='R')):
                counter.append(h)

    if(Orange_Red!=0):

        rand_people=np.repeat(['O','R'],min(round(number_of_people/2),Orange_Red))

        a=product(rand_people,repeat=2)

        for h in a:
            if(not(h[0]=='R' and h[1]=='O')):
                counter.append(h)

    if(Orange_Green!=0):

        rand_people=np.repeat(['O','G'],min(round(number_of_people/2),Orange_Green))

        a=product(rand_people,repeat=2)

        for h in a:
            if(not(h[0]=='G' and h[1]=='O')):
                counter.append(h)

    if(Green_Red!=0):

        rand_people=np.repeat(['G','R'],min(round(number_of_people/2),Green_Red))

        a=product(rand_people,repeat=2)

        for h in a:
            if(not(h[0]=='R' and h[1]=='G')):
                counter.append(h)

    if(Green_Orange!=0):

        rand_people=np.repeat(['G','O'],min(round(number_of_people/2),Green_Orange))

        a=product(rand_people,repeat=2)

        for h in a:
            if(not(h[0]=='O' and h[1]=='G')):
                counter.append(h)

    print(len(set(counter)))

main()
