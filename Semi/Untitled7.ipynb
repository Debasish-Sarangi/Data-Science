# %%
import numpy as np
from itertools import product
number_of_people = int(input().strip())
Red_Orange= int(input().strip())
Red_Green= int(input().strip())
Orange_Red= int(input().strip())
Orange_Green = int(input().strip())
Green_Red= int(input().strip())
Green_Orange= int(input().strip())

counter=[]
if(Red_Orange!=0):

    if (number_of_people%3==0 ):
        rand_people=np.repeat(['R','O'],number_of_people/3)
    elif(number_of_people%2==0 ):
        rand_people=np.repeat(['R','O'],number_of_people/2)

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='O' and h[1]=='R') ):
            counter.append(h)


if(Red_Green!=0):

    if (number_of_people%3==0 ):
        rand_people=np.repeat(['R','G'],number_of_people/3)
    elif(number_of_people%2==0 ):
        rand_people=np.repeat(['R','G'],number_of_people/2)

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='G' and h[1]=='R')):
            counter.append(h)

if(Orange_Red!=0):
    if (number_of_people%3==0 ):
        rand_people=np.repeat(['O','R'],number_of_people/3)
    elif(number_of_people%2==0 ):
        rand_people=np.repeat(['O','R'],number_of_people/2)

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='R' and h[1]=='O')):
            counter.append(h)

if(Orange_Green!=0):
    if (number_of_people%3==0 ):
        rand_people=np.repeat(['O','G'],number_of_people/3)
    elif(number_of_people%2==0 ):
        rand_people=np.repeat(['O','G'],number_of_people/2)

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='G' and h[1]=='O')):
            counter.append(h)

if(Green_Red!=0):
    if (number_of_people%3==0 ):
        rand_people=np.repeat(['G','R'],number_of_people/3)
    elif(number_of_people%2==0 ):
        rand_people=np.repeat(['G','R'],number_of_people/2)

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='R' and h[1]=='G')):
            counter.append(h)

if(Green_Orange!=0):
    if (number_of_people%3==0 ):
        rand_people=np.repeat(['G','O'],number_of_people/3)
    elif(number_of_people%2==0 ):
        rand_people=np.repeat(['G','O'],number_of_people/2)

    a=product(rand_people,repeat=Red_Orange*2)

    for h in a:
        if(not(h[0]=='O' and h[1]=='G')):
            counter.append(h)

            
print(set(counter))
print(len(set(counter)))
# Out:
# 2
# 1
# 1
# 1
# 1
# 0
# 0
# {('R', 'G'), ('R', 'R'), ('O', 'G'), ('O', 'R'), ('R', 'O'), ('O', 'O'), ('G', 'G')}
# 7

# %%
import numpy as np
from itertools import product
number_of_people = int(input().strip())
Red_Orange= int(input().strip())
Red_Green= int(input().strip())
Orange_Red= int(input().strip())
Orange_Green = int(input().strip())
Green_Red= int(input().strip())
Green_Orange= int(input().strip())
# Out:
# 6
# 2
# 2
# 2
# 2
# 2
# 2

# %%
counter=[]
cnt=0
red=0
mn=0
rnd=round(number_of_people/2)
if(Red_Orange!=0):

    mn=min(rnd,Red_Orange)
    rand_people=np.repeat(['R','O'],mn)
    red=red+((mn**2))

    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='O' and h[1]=='R')):
            cnt=cnt+1


if(Red_Green!=0):
    mn=min(rnd,Red_Green)
    rand_people=np.repeat(['R','G'],mn)
    red=red+((mn**2))
    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='G' and h[1]=='R') ):
            counter.append(h)
            

if(Orange_Red!=0):
    mn=min(rnd,Orange_Red)
    rand_people=np.repeat(['O','R'],mn)
    red=red+((mn**2))
    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='R' and h[1]=='O')):
            counter.append(h)

if(Orange_Green!=0):
    mn=min(rnd,Orange_Green)
    rand_people=np.repeat(['O','G'],mn)
    red=red+((mn**2))
    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='G' and h[1]=='O')):
            counter.append(h)

if(Green_Red!=0):
    mn=min(rnd,Green_Red)
    rand_people=np.repeat(['G','R'],mn)
    red=red+((mn**2))
    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='R' and h[1]=='G')):
            counter.append(h)

if(Green_Orange!=0):
    mn=min(rnd,Green_Orange)
    rand_people=np.repeat(['G','O'],mn)
    red=red+((mn**2))
    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='O' and h[1]=='G')):
            counter.append(h)

#print((len(counter)-red)+2)
print(counter)
# Out:
# 38
# [('R', 'R'), ('R', 'R'), ('R', 'G'), ('R', 'G'), ('R', 'R'), ('R', 'R'), ('R', 'G'), ('R', 'G'), ('G', 'G'), ('G', 'G'), ('G', 'G'), ('G', 'G'), ('O', 'O'), ('O', 'O'), ('O', 'R'), ('O', 'R'), ('O', 'O'), ('O', 'O'), ('O', 'R'), ('O', 'R'), ('R', 'R'), ('R', 'R'), ('R', 'R'), ('R', 'R'), ('O', 'O'), ('O', 'O'), ('O', 'G'), ('O', 'G'), ('O', 'O'), ('O', 'O'), ('O', 'G'), ('O', 'G'), ('G', 'G'), ('G', 'G'), ('G', 'G'), ('G', 'G'), ('G', 'G'), ('G', 'G'), ('G', 'R'), ('G', 'R'), ('G', 'G'), ('G', 'G'), ('G', 'R'), ('G', 'R'), ('R', 'R'), ('R', 'R'), ('R', 'R'), ('R', 'R'), ('G', 'G'), ('G', 'G'), ('G', 'O'), ('G', 'O'), ('G', 'G'), ('G', 'G'), ('G', 'O'), ('G', 'O'), ('O', 'O'), ('O', 'O'), ('O', 'O'), ('O', 'O')]

# %%
counter=[]
if(Orange_Green!=0):
    
    rand_people=np.repeat(['O','G'],min(round(number_of_people/2),Orange_Green))

    a=product(rand_people,repeat=2)

    for h in a:
        if(not((h[0]=='G' and h[1]=='O') or (h[0]=='O' and h[1]=='R') or (h[0]=='G' and h[1]=='R') or (h[0]=='G' and h[1]=='R'))):
            counter.append(h)
            
print(len(counter))            
print(len(set(counter)))

print(counter)
print(set(counter))
# Out:
# 3
# 3
# [('O', 'O'), ('O', 'G'), ('G', 'G')]
# {('O', 'G'), ('O', 'O'), ('G', 'G')}

# %%
counter=[]

if(Red_Orange!=0):

 
    rand_people=np.repeat(['R','O'],2)
    

    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='O' and h[1]=='R') ):
            counter.append(h)

print(counter)
print((len(counter)-(2*(mn**2))+2))
# Out:
# [('R', 'R'), ('R', 'O'), ('O', 'O')]
# -3

# %%
counter=[]
if(Green_Red!=0):
    
    rand_people=np.repeat(['G','R'],min(round(number_of_people/2),Green_Red))

    a=product(rand_people,repeat=2)

    for h in a:
        counter.append(h)
        #if(not(h[0]=='R' and h[1]=='G')):
            #counter.append(h)
print(set(counter))
# Out:
# set()

# %%
def main():

    import numpy as np
    from itertools import product
    number_of_people = int(input().strip())
    Red_Orange= int(input().strip())
    Red_Green= int(input().strip())
    Orange_Red= int(input().strip())
    Orange_Green = int(input().strip())
    Green_Red= int(input().strip())
    Green_Orange= int(input().strip())

    counter=[]
    rnd=round(number_of_people/2)
    if(Red_Orange!=0):


        rand_people=np.repeat(['R','O'],min(rnd,Red_Orange))


        a=product(rand_people,repeat=2)

        for h in a:
            if(not(h[0]=='O' and h[1]=='R') ):
                counter.append(h)


    if(Red_Green!=0):

        rand_people=np.repeat(['R','G'],min(rnd,Red_Green))

        a=product(rand_people,repeat=2)

        for h in a:
            if(not(h[0]=='G' and h[1]=='R')):
                counter.append(h)

    if(Orange_Red!=0):

        rand_people=np.repeat(['O','R'],min(rnd,Orange_Red))

        a=product(rand_people,repeat=2)

        for h in a:
            if(not(h[0]=='R' and h[1]=='O')):
                counter.append(h)

    if(Orange_Green!=0):

        rand_people=np.repeat(['O','G'],min(rnd,Orange_Green))

        a=product(rand_people,repeat=2)

        for h in a:
            if(not(h[0]=='G' and h[1]=='O')):
                counter.append(h)

    if(Green_Red!=0):

        rand_people=np.repeat(['G','R'],min(rnd,Green_Red))

        a=product(rand_people,repeat=2)

        for h in a:
            if(not(h[0]=='R' and h[1]=='G')):
                counter.append(h)

    if(Green_Orange!=0):

        rand_people=np.repeat(['G','O'],min(rnd,Green_Orange))

        a=product(rand_people,repeat=2)

        for h in a:
            if(not(h[0]=='O' and h[1]=='G')):
                counter.append(h)

    print(len(set(counter)))

main()
# Out:
# 63
# 10
# 10
# 10
# 10
# 10
# 10
# 9

# %%
counter=[]
cnt=0
mn=0
rnd=round(number_of_people/2)
if(Red_Orange!=0):

    mn=min(rnd,Red_Orange)
    rand_people=np.repeat(['R','O'],mn)


    a=product(rand_people,repeat=2)

    for h in a:
        if(not(h[0]=='O' and h[1]=='R')):
            cnt=cnt+1

cnt=cnt-2*(mn**2)
print(cnt)
# Out:
# 1
