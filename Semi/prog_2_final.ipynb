# %%
def main():
    import numpy as np
    from itertools import product
    number_of_people = int(input().strip())
    Red_Orange= int(input().strip())
    Red_Green= int(input().strip())
    Orange_Red= int(input().strip())
    Orange_Green = int(input().strip())
    Green_Red= int(input().strip())
    Green_Orange= int(input().strip())

    counter=[]
    if(Red_Orange!=0):

        if (number_of_people%3==0 ):
            rand_people=np.repeat(['R','O'],number_of_people/3)
        elif(number_of_people%2==0 ):
            rand_people=np.repeat(['R','O'],number_of_people/2)

        a=product(rand_people,repeat=Red_Orange*2)

        for h in a:
            if(not(h[0]=='O' and h[1]=='R') ):
                counter.append(h)


    if(Red_Green!=0):

        if (number_of_people%3==0 ):
            rand_people=np.repeat(['R','G'],number_of_people/3)
        elif(number_of_people%2==0 ):
            rand_people=np.repeat(['R','G'],number_of_people/2)

        a=product(rand_people,repeat=Red_Orange*2)

        for h in a:
            if(not(h[0]=='G' and h[1]=='R')):
                counter.append(h)

    if(Orange_Red!=0):
        if (number_of_people%3==0 ):
            rand_people=np.repeat(['O','R'],number_of_people/3)
        elif(number_of_people%2==0 ):
            rand_people=np.repeat(['O','R'],number_of_people/2)

        a=product(rand_people,repeat=Red_Orange*2)

        for h in a:
            if(not(h[0]=='R' and h[1]=='O')):
                counter.append(h)

    if(Orange_Green!=0):
        if (number_of_people%3==0 ):
            rand_people=np.repeat(['O','G'],number_of_people/3)
        elif(number_of_people%2==0 ):
            rand_people=np.repeat(['O','G'],number_of_people/2)

        a=product(rand_people,repeat=Red_Orange*2)

        for h in a:
            if(not(h[0]=='G' and h[1]=='O')):
                counter.append(h)

    if(Green_Red!=0):
        if (number_of_people%3==0 ):
            rand_people=np.repeat(['G','R'],number_of_people/3)
        elif(number_of_people%2==0 ):
            rand_people=np.repeat(['G','R'],number_of_people/2)

        a=product(rand_people,repeat=Red_Orange*2)

        for h in a:
            if(not(h[0]=='R' and h[1]=='G')):
                counter.append(h)

    if(Green_Orange!=0):
        if (number_of_people%3==0 ):
            rand_people=np.repeat(['G','O'],number_of_people/3)
        elif(number_of_people%2==0 ):
            rand_people=np.repeat(['G','O'],number_of_people/2)

        a=product(rand_people,repeat=Red_Orange*2)

        for h in a:
            if(not(h[0]=='O' and h[1]=='G')):
                counter.append(h)


    print(len(set(counter)))
main()
# Out:
# 3
# 2
# 2
# 1
# 0
# 2
# 2
# [('R', 'R', 'R', 'R'), ('R', 'R', 'R', 'O'), ('R', 'R', 'O', 'R'), ('R', 'R', 'O', 'O'), ('R', 'O', 'R', 'R'), ('R', 'O', 'R', 'O'), ('R', 'O', 'O', 'R'), ('R', 'O', 'O', 'O'), ('O', 'O', 'R', 'R'), ('O', 'O', 'R', 'O'), ('O', 'O', 'O', 'R'), ('O', 'O', 'O', 'O'), ('R', 'R', 'R', 'R'), ('R', 'R', 'R', 'G'), ('R', 'R', 'G', 'R'), ('R', 'R', 'G', 'G'), ('R', 'G', 'R', 'R'), ('R', 'G', 'R', 'G'), ('R', 'G', 'G', 'R'), ('R', 'G', 'G', 'G'), ('G', 'G', 'R', 'R'), ('G', 'G', 'R', 'G'), ('G', 'G', 'G', 'R'), ('G', 'G', 'G', 'G'), ('O', 'O', 'O', 'O'), ('O', 'O', 'O', 'R'), ('O', 'O', 'R', 'O'), ('O', 'O', 'R', 'R'), ('O', 'R', 'O', 'O'), ('O', 'R', 'O', 'R'), ('O', 'R', 'R', 'O'), ('O', 'R', 'R', 'R'), ('R', 'R', 'O', 'O'), ('R', 'R', 'O', 'R'), ('R', 'R', 'R', 'O'), ('R', 'R', 'R', 'R'), ('G', 'G', 'G', 'G'), ('G', 'G', 'G', 'R'), ('G', 'G', 'R', 'G'), ('G', 'G', 'R', 'R'), ('G', 'R', 'G', 'G'), ('G', 'R', 'G', 'R'), ('G', 'R', 'R', 'G'), ('G', 'R', 'R', 'R'), ('R', 'R', 'G', 'G'), ('R', 'R', 'G', 'R'), ('R', 'R', 'R', 'G'), ('R', 'R', 'R', 'R'), ('G', 'G', 'G', 'G'), ('G', 'G', 'G', 'O'), ('G', 'G', 'O', 'G'), ('G', 'G', 'O', 'O'), ('G', 'O', 'G', 'G'), ('G', 'O', 'G', 'O'), ('G', 'O', 'O', 'G'), ('G', 'O', 'O', 'O'), ('O', 'O', 'G', 'G'), ('O', 'O', 'G', 'O'), ('O', 'O', 'O', 'G'), ('O', 'O', 'O', 'O')]
# {('G', 'G', 'R', 'R'), ('G', 'G', 'O', 'G'), ('G', 'O', 'G', 'G'), ('O', 'O', 'G', 'G'), ('R', 'O', 'R', 'R'), ('R', 'R', 'R', 'R'), ('R', 'R', 'G', 'R'), ('G', 'G', 'O', 'O'), ('O', 'R', 'O', 'R'), ('G', 'O', 'G', 'O'), ('O', 'O', 'R', 'O'), ('G', 'R', 'R', 'R'), ('O', 'O', 'G', 'O'), ('R', 'O', 'O', 'O'), ('R', 'G', 'R', 'G'), ('O', 'O', 'R', 'R'), ('O', 'O', 'O', 'G'), ('R', 'G', 'G', 'G'), ('R', 'O', 'O', 'R'), ('O', 'O', 'O', 'O'), ('R', 'R', 'O', 'O'), ('G', 'O', 'O', 'G'), ('R', 'G', 'R', 'R'), ('O', 'O', 'O', 'R'), ('R', 'R', 'O', 'R'), ('R', 'G', 'G', 'R'), ('G', 'R', 'G', 'G'), ('G', 'O', 'O', 'O'), ('G', 'G', 'G', 'G'), ('O', 'R', 'R', 'O'), ('G', 'G', 'R', 'G'), ('G', 'R', 'R', 'G'), ('G', 'G', 'G', 'O'), ('O', 'R', 'R', 'R'), ('G', 'R', 'G', 'R'), ('R', 'R', 'R', 'G'), ('R', 'R', 'G', 'G'), ('G', 'G', 'G', 'R'), ('R', 'O', 'R', 'O'), ('R', 'R', 'R', 'O'), ('O', 'R', 'O', 'O')}
# 41
