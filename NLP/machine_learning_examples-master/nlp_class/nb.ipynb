# %%
# Naive Bayes spam detection for NLP class, which can be found at:
# https://deeplearningcourses.com/c/data-science-natural-language-processing-in-python
# https://www.udemy.com/data-science-natural-language-processing-in-python
# dataset: https://archive.ics.uci.edu/ml/datasets/Spambase

# Author: http://lazyprogrammer.me
from __future__ import print_function, division
from builtins import range
# Note: you may need to update your version of future
# sudo pip install -U future


from sklearn.naive_bayes import MultinomialNB
import pandas as pd
import numpy as np

# Note: technically multinomial NB is for "counts", but the documentation says
#       it will work for other types of "counts", like tf-idf, so it should
#       also work for our "word proportions"

data = pd.read_csv('spambase.data').values # use pandas for convenience
np.random.shuffle(data) # shuffle each row in-place, but preserve the row

X = data[:,:48]
Y = data[:,-1]

# last 100 rows will be test
Xtrain = X[:-2000,]
Ytrain = Y[:-2000,]
Xtest = X[-2000:,]
Ytest = Y[-2000:,]

from sklearn.metrics import confusion_matrix


model = MultinomialNB()
model.fit(Xtrain, Ytrain)
print("Classification rate for NB:", model.score(Xtest, Ytest))
y_pred = model.predict(Xtest)
cm = confusion_matrix(Ytest, y_pred)
print(cm)

##### you can use ANY model! #####
from sklearn.ensemble import AdaBoostClassifier

model = AdaBoostClassifier()
model.fit(Xtrain, Ytrain)
print("Classification rate for AdaBoost:", model.score(Xtest, Ytest))


cm = confusion_matrix(Ytest, y_pred)
print(cm)
# Out:
# Classification rate for NB: 0.872
# [[1017  209]
#  [  47  727]]
# Classification rate for AdaBoost: 0.9195
# [[1017  209]
#  [  47  727]]

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(n_components = 48, kernel = 'rbf')
Xtrain = kpca.fit_transform(Xtrain)
Xtest = kpca.transform(Xtest)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(Xtrain, Xtest, Ytrain, Ytest)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:06<00:00,  4.62it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.92               0.91     0.91      0.91
# LGBMClassifier                     0.92               0.91     0.91      0.92
# LogisticRegression                 0.91               0.91     0.91      0.91
# LinearSVC                          0.91               0.91     0.91      0.91
# RandomForestClassifier             0.91               0.91     0.91      0.91
# ExtraTreesClassifier               0.91               0.90     0.90      0.91
# CalibratedClassifierCV             0.91               0.90     0.90      0.91
# SVC                                0.91               0.90     0.90      0.91
# SGDClassifier                      0.89               0.90     0.90      0.90
# NearestCentroid                    0.90               0.90     0.90      0.90
# NuSVC                              0.90               0.89     0.89      0.90
# RidgeClassifierCV                  0.90               0.89     0.89      0.90
# LinearDiscriminantAnalysis         0.90               0.88     0.88      0.89
# RidgeClassifier                    0.90               0.88     0.88      0.89
# AdaBoostClassifier                 0.89               0.88     0.88      0.88
# BaggingClassifier                  0.89               0.87     0.87      0.89
# Perceptron                         0.87               0.87     0.87      0.87
# PassiveAggressiveClassifier        0.87               0.86     0.86      0.87
# KNeighborsClassifier               0.87               0.86     0.86      0.87
# LabelSpreading                     0.86               0.86     0.86      0.86
# LabelPropagation                   0.86               0.86     0.86      0.86
# QuadraticDiscriminantAnalysis      0.82               0.85     0.85      0.83
# DecisionTreeClassifier             0.85               0.84     0.84      0.85
# GaussianNB                         0.77               0.80     0.80      0.77
# ExtraTreeClassifier                0.80               0.79     0.79      0.80
# BernoulliNB                        0.79               0.77     0.77      0.79
# DummyClassifier                    0.52               0.50     0.50      0.52
# CheckingClassifier                 0.61               0.50     0.50      0.46
#
#                                Time Taken
# Model
# XGBClassifier                        0.57
# LGBMClassifier                       0.43
# LogisticRegression                   0.06
# LinearSVC                            0.13
# RandomForestClassifier               0.75
# ExtraTreesClassifier                 0.36
# CalibratedClassifierCV               0.50
# SVC                                  0.25
# SGDClassifier                        0.04
# NearestCentroid                      0.03
# NuSVC                                0.36
# RidgeClassifierCV                    0.05
# LinearDiscriminantAnalysis           0.05
# RidgeClassifier                      0.03
# AdaBoostClassifier                   0.58
# BaggingClassifier                    0.42
# Perceptron                           0.02
# PassiveAggressiveClassifier          0.03
# KNeighborsClassifier                 0.51
# LabelSpreading                       0.50
# LabelPropagation                     0.50
# QuadraticDiscriminantAnalysis        0.05
# DecisionTreeClassifier               0.08
# GaussianNB                           0.04
# ExtraTreeClassifier                  0.03
# BernoulliNB                          0.05
# DummyClassifier                      0.03
# CheckingClassifier                   0.03

# %%
dat=[[1,2,3],[4,5,6],[7,8,9]]
np.random.shuffle(dat)
dat
# Out:
# [[4, 5, 6], [1, 2, 3], [7, 8, 9]]
