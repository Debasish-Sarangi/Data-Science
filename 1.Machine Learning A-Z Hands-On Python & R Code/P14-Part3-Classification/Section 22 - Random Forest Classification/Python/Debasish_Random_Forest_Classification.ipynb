# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from lazypredict.Supervised import LazyClassifier
dataset = pd.read_csv('Social_Network_Ads.csv')
X = dataset.iloc[:, [2, 3]].values
y = dataset.iloc[:, -1].values
# Out:
# c:\users\dsarangi\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = None)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)
explainedVar = pca.explained_variance_ratio_
print(explainedVar)
# Out:
# [9.99999916e-01 8.39849268e-08]

# %%
from sklearn.decomposition import KernelPCA
kpca = PCA(n_components = None)
X_train = kpca.fit_transform(X_train)
X_test = kpca.transform(X_test)
explainedVar = kpca.explained_variance_ratio_
print(explainedVar)
# Out:
# [0.57095752 0.42904248]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components = None)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)
explainedVar = lda.explained_variance_ratio_
print(explainedVar)
# Out:
# [1.]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components = 1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)
explainedVar = lda.explained_variance_ratio_
print(explainedVar)
# Out:
# [1.]

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(n_components = 2, kernel = 'rbf')
X_train = kpca.fit_transform(X_train)
X_test = kpca.transform(X_test)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components = 1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 1)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)
explained_variance = pca.explained_variance_ratio_

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 30.99it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreeClassifier                0.94               0.94     0.94      0.94
# NearestCentroid                    0.93               0.93     0.93      0.93
# ExtraTreesClassifier               0.94               0.93     0.93      0.94
# BernoulliNB                        0.92               0.92     0.92      0.92
# LGBMClassifier                     0.93               0.92     0.92      0.93
# LabelPropagation                   0.93               0.92     0.92      0.93
# NuSVC                              0.93               0.92     0.92      0.93
# BaggingClassifier                  0.93               0.92     0.92      0.93
# LinearDiscriminantAnalysis         0.93               0.92     0.92      0.93
# LabelSpreading                     0.93               0.92     0.92      0.93
# RandomForestClassifier             0.93               0.92     0.92      0.93
# KNeighborsClassifier               0.93               0.92     0.92      0.93
# SVC                                0.93               0.92     0.92      0.93
# XGBClassifier                      0.93               0.92     0.92      0.93
# SGDClassifier                      0.91               0.92     0.92      0.91
# QuadraticDiscriminantAnalysis      0.92               0.91     0.91      0.92
# RidgeClassifierCV                  0.92               0.91     0.91      0.92
# RidgeClassifier                    0.92               0.91     0.91      0.92
# GaussianNB                         0.92               0.91     0.91      0.92
# LinearSVC                          0.91               0.89     0.89      0.91
# LogisticRegression                 0.91               0.89     0.89      0.91
# DecisionTreeClassifier             0.89               0.88     0.88      0.89
# AdaBoostClassifier                 0.89               0.88     0.88      0.89
# CalibratedClassifierCV             0.90               0.88     0.88      0.90
# PassiveAggressiveClassifier        0.80               0.79     0.79      0.80
# Perceptron                         0.73               0.74     0.74      0.74
# CheckingClassifier                 0.68               0.50     0.50      0.55
# DummyClassifier                    0.55               0.49     0.49      0.55
#
#                                Time Taken
# Model
# ExtraTreeClassifier                  0.01
# NearestCentroid                      0.01
# ExtraTreesClassifier                 0.14
# BernoulliNB                          0.01
# LGBMClassifier                       0.07
# LabelPropagation                     0.02
# NuSVC                                0.02
# BaggingClassifier                    0.04
# LinearDiscriminantAnalysis           0.01
# LabelSpreading                       0.01
# RandomForestClassifier               0.19
# KNeighborsClassifier                 0.01
# SVC                                  0.01
# XGBClassifier                        0.05
# SGDClassifier                        0.01
# QuadraticDiscriminantAnalysis        0.01
# RidgeClassifierCV                    0.01
# RidgeClassifier                      0.02
# GaussianNB                           0.02
# LinearSVC                            0.01
# LogisticRegression                   0.01
# DecisionTreeClassifier               0.01
# AdaBoostClassifier                   0.14
# CalibratedClassifierCV               0.03
# PassiveAggressiveClassifier          0.01
# Perceptron                           0.01
# CheckingClassifier                   0.01
# DummyClassifier                      0.02
