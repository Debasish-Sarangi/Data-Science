# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
from lazypredict.Supervised import LazyRegressor

init_notebook_mode(connected=True)
cf.go_offline()
# Out:
# c:\users\dsarangi\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning:
#
# The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
dataset = pd.read_csv('50_Startups.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [3])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
X= X[:,1:]

# %%
offset = int(X.shape[0] * 0.9)
X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]
reg = LazyRegressor(verbose=0,ignore_warnings=False, custom_metric=None )
models,predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  79%|████████████████████████████████████████████████████████████████▊                 | 34/43 [00:01<00:00, 17.48it/s]
# RANSACRegressor model failed to execute
# `min_samples` may not be larger than number of samples: n_samples = 45.
# 100%|██████████████████████████████████████████████████████████████████████████████████| 43/43 [00:01<00:00, 23.64it/s]
# StackingRegressor model failed to execute
# __init__() missing 1 required positional argument: 'estimators'
#                                                       R-Squared  \
# Model
# PassiveAggressiveRegressor                                -1.32
# LinearSVR                                                 -6.27
# MLPRegressor                                              -6.28
# TransformedTargetRegressor                                -8.86
# LinearRegression                                          -8.86
# KernelRidge                                              -11.01
# ExtraTreesRegressor                                      -12.87
# OrthogonalMatchingPursuit                                -14.51
# RandomForestRegressor                                    -14.61
# BaggingRegressor                                         -14.87
# DecisionTreeRegressor                                    -16.56
# ExtraTreeRegressor                                       -16.56
# SVR                                                      -17.36
# GradientBoostingRegressor                                -19.01
# AdaBoostRegressor                                        -19.20
# SGDRegressor                                             -19.27
# XGBRegressor                                             -19.28
# OrthogonalMatchingPursuitCV                              -19.63
# PoissonRegressor                                         -19.73
# LassoLarsCV                                              -20.27
# LassoLars                                                -20.34
# Lasso                                                    -20.70
# HuberRegressor                                           -21.27
# LassoCV                                                  -21.63
# GammaRegressor                                           -21.98
# Ridge                                                    -22.00
# RidgeCV                                                  -22.13
# ElasticNet                                               -22.23
# GeneralizedLinearRegressor                               -22.32
# TweedieRegressor                                         -22.32
# LGBMRegressor                                            -22.47
# BayesianRidge                                            -22.47
# HistGradientBoostingRegressor                            -22.47
# ElasticNetCV                                             -22.47
# DummyRegressor                                           -22.47
# LassoLarsIC                                              -22.47
# NuSVR                                                    -22.86
# KNeighborsRegressor                                      -50.29
# GaussianProcessRegressor                                -191.72
# LarsCV                        -57644583184498683400090025984.00
# Lars                          -57644583184498683400090025984.00
#
#                                                 RMSE  Time Taken
# Model
# PassiveAggressiveRegressor                  25179.22        0.03
# LinearSVR                                   44585.15        0.01
# MLPRegressor                                44627.35        0.24
# TransformedTargetRegressor                  51910.87        0.02
# LinearRegression                            51910.87        0.01
# KernelRidge                                 57293.03        0.01
# ExtraTreesRegressor                         61589.11        0.15
# OrthogonalMatchingPursuit                   65126.54        0.01
# RandomForestRegressor                       65326.00        0.14
# BaggingRegressor                            65865.50        0.03
# DecisionTreeRegressor                       69284.52        0.01
# ExtraTreeRegressor                          69284.52        0.01
# SVR                                         70842.59        0.01
# GradientBoostingRegressor                   73958.97        0.04
# AdaBoostRegressor                           74315.98        0.07
# SGDRegressor                                74445.01        0.03
# XGBRegressor                                74457.72        0.08
# OrthogonalMatchingPursuitCV                 75095.56        0.02
# PoissonRegressor                            75286.52        0.01
# LassoLarsCV                                 76254.69        0.12
# LassoLars                                   76379.39        0.03
# Lasso                                       77021.37        0.03
# HuberRegressor                              78021.46        0.07
# LassoCV                                     78663.65        0.07
# GammaRegressor                              79265.03        0.01
# Ridge                                       79298.58        0.01
# RidgeCV                                     79523.74        0.01
# ElasticNet                                  79694.47        0.01
# GeneralizedLinearRegressor                  79838.66        0.01
# TweedieRegressor                            79838.66        0.02
# LGBMRegressor                               80109.75        0.02
# BayesianRidge                               80109.75        0.01
# HistGradientBoostingRegressor               80109.75        0.07
# ElasticNetCV                                80109.75        0.05
# DummyRegressor                              80109.75        0.01
# LassoLarsIC                                 80109.75        0.03
# NuSVR                                       80763.47        0.01
# KNeighborsRegressor                        118410.93        0.02
# GaussianProcessRegressor                   229537.81        0.01
# LarsCV                        3969798981875520512.00        0.17
# Lars                          3969798981875520512.00        0.04

# %%
X = np.append(arr=np.ones((50,1)).astype(int), values=X , axis= 1 )
X
import statsmodels.api as sm
X_opt = np.array(X[:, [0, 1, 2, 3, 4, 5]], dtype=float)
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Fri, 11 Sep 2020   Prob (F-statistic):           1.34e-27
# Time:                        18:43:42   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.013e+04   6884.820      7.281      0.000    3.62e+04     6.4e+04
# x1           198.7888   3371.007      0.059      0.953   -6595.030    6992.607
# x2           -41.8870   3256.039     -0.013      0.990   -6604.003    6520.229
# x3             0.8060      0.046     17.369      0.000       0.712       0.900
# x4            -0.0270      0.052     -0.517      0.608      -0.132       0.078
# x5             0.0270      0.017      1.574      0.123      -0.008       0.062
# ==============================================================================
# Omnibus:                       14.782   Durbin-Watson:                   1.283
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.266
# Skew:                          -0.948   Prob(JB):                     2.41e-05
# Kurtosis:                       5.572   Cond. No.                     1.45e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.45e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
